# %% [markdown]
# # Implementation

# %% [markdown]
# ## Packages

# %%
# data elaboration functions
import pandas as pd
from six.moves import collections_abc
import string
import numpy as np

# datetime functions
import datetime as dt

# file management functions
import os
import sys
import opendatasets as od
import pickle
from pathlib import Path

# plot functions
import matplotlib.pyplot as plt
# %matplotlib inline

# data science functions
import matplotlib.pyplot as plt
from kneed import KneeLocator
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler, scale
from sklearn.metrics import mean_absolute_error
import joblib
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import xgboost as xgb

# statistical functions
from scipy.stats.mstats import winsorize

# configuration file
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# custom functions
from Code.Profiling.Intermittent.intermittent import Intermittent
from Code.Utils.utils import Utils
from Code.Scoring.kpi import Kpi
from Code.Scoring.forecast import Forecasting
from Code.Scoring.train import Training
from Code.Scoring.train_test import TrainTest
from Code.Scoring.scoring import Scoring
from Code.Regressors.regressors import Regressors
from Code.Plotting.plots import Plots
from Configuration.config import cfg_path

# %% [markdown]
# ## Setup

# %%
# od.download("https://www.kaggle.com/arashnic/building-sites-power-consumption-dataset/download")
root = Path(os.getcwd()).parent
dataset_path = os.path.join(root, cfg_path.data_dir.input_path)

# %% [markdown]
# ## Load Data

# %%
df_final = pd.read_pickle(os.path.join(
    root, cfg_path.data_dir.output_path, 'df_final.pkl'))
df_final.head()
# Out:
#    site_id  timestamp     obs_id  forecast_id         value  holidays  \
# 0        2 2015-11-02  7390465.0         26.0  1.492533e+06         0
# 1        3 2015-11-02        NaN          NaN           NaN         0
# 2        5 2015-11-02        NaN          NaN           NaN         0
# 3        6 2015-11-02  1413383.0        129.0  8.541479e+05         0
# 4        7 2015-11-02        NaN          NaN           NaN         0
#
#    day_off       surface  base_temperature  wd_mon  ...  month_05  month_06  \
# 0        0   6098.278376              18.0       1  ...         0         0
# 1        0  10556.293605              18.0       1  ...         0         0
# 2        0  12541.181277              18.0       1  ...         0         0
# 3        0   9150.195373              18.0       1  ...         0         0
# 4        0  15168.125971              18.0       1  ...         0         0
#
#    month_07  month_08  month_09  month_10  month_11  month_12  months_days  \
# 0         0         0         0         0         1         0        11/02
# 1         0         0         0         0         1         0        11/02
# 2         0         0         0         0         1         0        11/02
# 3         0         0         0         0         1         0        11/02
# 4         0         0         0         0         1         0        11/02
#
#    temperature_asis
# 0         13.247917
# 1         13.252083
# 2         13.241667
# 3         13.243750
# 4         13.245833
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Parameter setup

# %%
id = 'site_id'
list_unique_id = ['site_id', 'timestamp']
list_temp = ['temp']
y = 'value'
date_var = Utils.find_date(df_final)
# Out:
# find_date, date_col found: ['timestamp']

# %% [markdown]
# ## Working dataframe

# %%
# Defining working dataframe by removing potential null values in y variable
df = df_final.loc[~df_final[y].isnull(),].copy()
print('Id available', list(df[id].unique()))
# Out:
# Id available [2, 6, 8, 9, 10, 13, 16, 17, 18, 19, 21, 22, 25, 26, 27, 29, 32, 33, 39, 40, 41, 42, 51, 45, 47, 48, 50, 49, 57, 7, 44, 20, 46, 38, 52, 12]

# %% [markdown]
# # Compute intermittent indicators

# %%
# Winsorizing parameters
highest = 0.05
lowest = 0.05

# Identifying intermittent time series parameters
threshold = 250
perc = 0.01
quant = 0.999

# %% [markdown]
# ### Choose indicator function

# %%
# Applying indicator function ('compute_indicator_values' or 'enh_compute_indicator_values')
func = 'compute_indicator_values'
df_scoring = df.loc[:, [id, y]].groupby(id).apply(lambda x: Intermittent.call_intermittent_function(func,
    np.array(x), threshold, perc, quant, highest, lowest)).reset_index(level=id)

# %% [markdown]
# ## Profiling intermittent time series

# %%
# Excluding the ids for which the indicators are np.NaN
df_scoring_no_nan = df_scoring.dropna()
list_nan = list(set(df_scoring[id]) - set(df_scoring_no_nan[id]))
print('List of nan ids', list_nan)

# Classify intermittent TS
thres_cv2_constant = 0.01
thres_cv2 = 2
thres_adi = 3
thres_sddi = 6.2
min_time_cons = 2
type = df_scoring_no_nan['type'].unique()[0]

df_profiling = Intermittent.classify_intermittent(df_scoring_no_nan, type, thres_cv2_constant, thres_cv2, thres_adi, thres_sddi, min_time_cons)

# Dictionary
list_of_profiles = ['regular', 'constant_zero', 'constant', 'intermittent',
                    'lumpy', 'erratic', 'unforecastable_time', 'unforecastable_quantity']
dict_profiling = {}
for c in list_of_profiles:
    dict_profiling[c] = list(
        df_profiling.loc[df_profiling.profile == c, id].unique())
    print(id, c, dict_profiling[c])
# Out:
# List of nan ids []
# classify_intermittent: regular ids 35
# classify_intermittent: no constant_zero ids
# classify_intermittent: constant ids 1
# classify_intermittent: no intermittent ids
# classify_intermittent: no lumpy ids
# classify_intermittent: no erratic ids
# classify_intermittent: no unforecastable_time ids
# classify_intermittent: no unforecastable_quantity ids
# site_id regular [2, 6, 7, 8, 9, 10, 12, 13, 16, 17, 18, 19, 20, 21, 22, 25, 27, 29, 32, 33, 38, 39, 40, 41, 42, 44, 45, 46, 47, 48, 49, 50, 51, 52, 57]
# site_id constant_zero []
# site_id constant [26]
# site_id intermittent []
# site_id lumpy []
# site_id erratic []
# site_id unforecastable_time []
# site_id unforecastable_quantity []
# c:\Users\mabellani\.conda\envs\forecasting_energy\lib\site-packages\pandas\core\indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value

# %% [markdown]
# ### Plotting profiled series

# %%
for profile in list_of_profiles:
    df_to_plot = df.loc[df[id].isin(list(dict_profiling[profile])), ]
    count = 1
    for i in list(df_to_plot[id].unique()):
        print('Plotting id:', i, 'as', count, 'of',
              len(list(df_to_plot[id].unique())))
        plot = Plots.sliding_line_plot(df_to_plot, y, id, i, chart_title="")
        folder_name = os.path.join(root, cfg_path.data_dir.plot_path, profile)
        Utils.create_folder_tree(folder_name)
        plot.write_html(os.path.join(folder_name, id + '_' + str(i) + '_profile_' + profile + ".html"))
        count = count + 1
# Out:
# Plotting id: 2 as 1 of 35
# find_date, date_col found: ['timestamp']
# sliding_line_plot: plotting Value site_id 2
# Successfully created the directory c:\Users\mabellani\OneDrive - Microsoft\Documents\REPOSITORY\dstoolkit-forecasting\Data/Plots\regular
# Plotting id: 6 as 2 of 35
# find_date, date_col found: ['timestamp']
# sliding_line_plot: plotting Value site_id 6
# Creation of the directory failed or already present c:\Users\mabellani\OneDrive - Microsoft\Documents\REPOSITORY\dstoolkit-forecasting\Data/Plots\regular
# Plotting id: 8 as 3 of 35
# find_date, date_col found: ['timestamp']
# sliding_line_plot: plotting Value site_id 8
# Creation of the directory failed or already present c:\Users\mabellani\OneDrive - Microsoft\Documents\REPOSITORY\dstoolkit-forecasting\Data/Plots\regular
# Plotting id: 9 as 4 of 35
# find_date, date_col found: ['timestamp']
# sliding_line_plot: plotting Value site_id 9
# Creation of the directory failed or already present c:\Users\mabellani\OneDrive - Microsoft\Documents\REPOSITORY\dstoolkit-forecasting\Data/Plots\regular
# Plotting id: 10 as 5 of 35
# find_date, date_col found: ['timestamp']
# sliding_line_plot: plotting Value site_id 10
# Creation of the directory failed or already present c:\Users\mabellani\OneDrive - Microsoft\Documents\REPOSITORY\dstoolkit-forecasting\Data/Plots\regular
# Plotting id: 13 as 6 of 35
# find_date, date_col found: ['timestamp']
# sliding_line_plot: plotting Value site_id 13
# Creation of the directory failed or already present c:\Users\mabellani\OneDrive - Microsoft\Documents\REPOSITORY\dstoolkit-forecasting\Data/Plots\regular
# Plotting id: 16 as 7 of 35
# find_date, date_col found: ['timestamp']
# sliding_line_plot: plotting Value site_id 16
# Creation of the directory failed or already present c:\Users\mabellani\OneDrive - Microsoft\Documents\REPOSITORY\dstoolkit-forecasting\Data/Plots\regular
# Plotting id: 17 as 8 of 35
# find_date, date_col found: ['timestamp']
# sliding_line_plot: plotting Value site_id 17
# Creation of the directory failed or already present c:\Users\mabellani\OneDrive - Microsoft\Documents\REPOSITORY\dstoolkit-forecasting\Data/Plots\regular
# Plotting id: 18 as 9 of 35
# find_date, date_col found: ['timestamp']
# sliding_line_plot: plotting Value site_id 18
# Creation of the directory failed or already present c:\Users\mabellani\OneDrive - Microsoft\Documents\REPOSITORY\dstoolkit-forecasting\Data/Plots\regular
# Plotting id: 19 as 10 of 35
# find_date, date_col found: ['timestamp']
# sliding_line_plot: plotting Value site_id 19
# Creation of the directory failed or already present c:\Users\mabellani\OneDrive - Microsoft\Documents\REPOSITORY\dstoolkit-forecasting\Data/Plots\regular
# Plotting id: 21 as 11 of 35
# find_date, date_col found: ['timestamp']
# sliding_line_plot: plotting Value site_id 21
# Creation of the directory failed or already present c:\Users\mabellani\OneDrive - Microsoft\Documents\REPOSITORY\dstoolkit-forecasting\Data/Plots\regular
# Plotting id: 22 as 12 of 35
# find_date, date_col found: ['timestamp']
# sliding_line_plot: plotting Value site_id 22
# Creation of the directory failed or already present c:\Users\mabellani\OneDrive - Microsoft\Documents\REPOSITORY\dstoolkit-forecasting\Data/Plots\regular
# Plotting id: 25 as 13 of 35
# find_date, date_col found: ['timestamp']
# sliding_line_plot: plotting Value site_id 25
# Creation of the directory failed or already present c:\Users\mabellani\OneDrive - Microsoft\Documents\REPOSITORY\dstoolkit-forecasting\Data/Plots\regular
# Plotting id: 27 as 14 of 35
# find_date, date_col found: ['timestamp']
# sliding_line_plot: plotting Value site_id 27
# Creation of the directory failed or already present c:\Users\mabellani\OneDrive - Microsoft\Documents\REPOSITORY\dstoolkit-forecasting\Data/Plots\regular
# Plotting id: 29 as 15 of 35
# find_date, date_col found: ['timestamp']
# sliding_line_plot: plotting Value site_id 29
# Creation of the directory failed or already present c:\Users\mabellani\OneDrive - Microsoft\Documents\REPOSITORY\dstoolkit-forecasting\Data/Plots\regular
# Plotting id: 32 as 16 of 35
# find_date, date_col found: ['timestamp']
# sliding_line_plot: plotting Value site_id 32
# Creation of the directory failed or already present c:\Users\mabellani\OneDrive - Microsoft\Documents\REPOSITORY\dstoolkit-forecasting\Data/Plots\regular
# Plotting id: 33 as 17 of 35
# find_date, date_col found: ['timestamp']
# sliding_line_plot: plotting Value site_id 33
# Creation of the directory failed or already present c:\Users\mabellani\OneDrive - Microsoft\Documents\REPOSITORY\dstoolkit-forecasting\Data/Plots\regular
# Plotting id: 39 as 18 of 35
# find_date, date_col found: ['timestamp']
# sliding_line_plot: plotting Value site_id 39
# Creation of the directory failed or already present c:\Users\mabellani\OneDrive - Microsoft\Documents\REPOSITORY\dstoolkit-forecasting\Data/Plots\regular
# Plotting id: 40 as 19 of 35
# find_date, date_col found: ['timestamp']
# sliding_line_plot: plotting Value site_id 40
# Creation of the directory failed or already present c:\Users\mabellani\OneDrive - Microsoft\Documents\REPOSITORY\dstoolkit-forecasting\Data/Plots\regular
# Plotting id: 41 as 20 of 35
# find_date, date_col found: ['timestamp']
# sliding_line_plot: plotting Value site_id 41
# Creation of the directory failed or already present c:\Users\mabellani\OneDrive - Microsoft\Documents\REPOSITORY\dstoolkit-forecasting\Data/Plots\regular
# Plotting id: 42 as 21 of 35
# find_date, date_col found: ['timestamp']
# sliding_line_plot: plotting Value site_id 42
# Creation of the directory failed or already present c:\Users\mabellani\OneDrive - Microsoft\Documents\REPOSITORY\dstoolkit-forecasting\Data/Plots\regular
# Plotting id: 51 as 22 of 35
# find_date, date_col found: ['timestamp']
# sliding_line_plot: plotting Value site_id 51
# Creation of the directory failed or already present c:\Users\mabellani\OneDrive - Microsoft\Documents\REPOSITORY\dstoolkit-forecasting\Data/Plots\regular
# Plotting id: 45 as 23 of 35
# find_date, date_col found: ['timestamp']
# sliding_line_plot: plotting Value site_id 45
# Creation of the directory failed or already present c:\Users\mabellani\OneDrive - Microsoft\Documents\REPOSITORY\dstoolkit-forecasting\Data/Plots\regular
# Plotting id: 47 as 24 of 35
# find_date, date_col found: ['timestamp']
# sliding_line_plot: plotting Value site_id 47
# Creation of the directory failed or already present c:\Users\mabellani\OneDrive - Microsoft\Documents\REPOSITORY\dstoolkit-forecasting\Data/Plots\regular
# Plotting id: 48 as 25 of 35
# find_date, date_col found: ['timestamp']
# sliding_line_plot: plotting Value site_id 48
# Creation of the directory failed or already present c:\Users\mabellani\OneDrive - Microsoft\Documents\REPOSITORY\dstoolkit-forecasting\Data/Plots\regular
# Plotting id: 50 as 26 of 35
# find_date, date_col found: ['timestamp']
# sliding_line_plot: plotting Value site_id 50
# Creation of the directory failed or already present c:\Users\mabellani\OneDrive - Microsoft\Documents\REPOSITORY\dstoolkit-forecasting\Data/Plots\regular
# Plotting id: 49 as 27 of 35
# find_date, date_col found: ['timestamp']
# sliding_line_plot: plotting Value site_id 49
# Creation of the directory failed or already present c:\Users\mabellani\OneDrive - Microsoft\Documents\REPOSITORY\dstoolkit-forecasting\Data/Plots\regular
# Plotting id: 57 as 28 of 35
# find_date, date_col found: ['timestamp']
# sliding_line_plot: plotting Value site_id 57
# Creation of the directory failed or already present c:\Users\mabellani\OneDrive - Microsoft\Documents\REPOSITORY\dstoolkit-forecasting\Data/Plots\regular
# Plotting id: 7 as 29 of 35
# find_date, date_col found: ['timestamp']
# sliding_line_plot: plotting Value site_id 7
# Creation of the directory failed or already present c:\Users\mabellani\OneDrive - Microsoft\Documents\REPOSITORY\dstoolkit-forecasting\Data/Plots\regular
# Plotting id: 44 as 30 of 35
# find_date, date_col found: ['timestamp']
# sliding_line_plot: plotting Value site_id 44
# Creation of the directory failed or already present c:\Users\mabellani\OneDrive - Microsoft\Documents\REPOSITORY\dstoolkit-forecasting\Data/Plots\regular
# Plotting id: 20 as 31 of 35
# find_date, date_col found: ['timestamp']
# sliding_line_plot: plotting Value site_id 20
# Creation of the directory failed or already present c:\Users\mabellani\OneDrive - Microsoft\Documents\REPOSITORY\dstoolkit-forecasting\Data/Plots\regular
# Plotting id: 46 as 32 of 35
# find_date, date_col found: ['timestamp']
# sliding_line_plot: plotting Value site_id 46
# Creation of the directory failed or already present c:\Users\mabellani\OneDrive - Microsoft\Documents\REPOSITORY\dstoolkit-forecasting\Data/Plots\regular
# Plotting id: 38 as 33 of 35
# find_date, date_col found: ['timestamp']
# sliding_line_plot: plotting Value site_id 38
# Creation of the directory failed or already present c:\Users\mabellani\OneDrive - Microsoft\Documents\REPOSITORY\dstoolkit-forecasting\Data/Plots\regular
# Plotting id: 52 as 34 of 35
# find_date, date_col found: ['timestamp']
# sliding_line_plot: plotting Value site_id 52
# Creation of the directory failed or already present c:\Users\mabellani\OneDrive - Microsoft\Documents\REPOSITORY\dstoolkit-forecasting\Data/Plots\regular
# Plotting id: 12 as 35 of 35
# find_date, date_col found: ['timestamp']
# sliding_line_plot: plotting Value site_id 12
# Creation of the directory failed or already present c:\Users\mabellani\OneDrive - Microsoft\Documents\REPOSITORY\dstoolkit-forecasting\Data/Plots\regular
# Plotting id: 26 as 1 of 1
# find_date, date_col found: ['timestamp']
# sliding_line_plot: plotting Value site_id 26
# Successfully created the directory c:\Users\mabellani\OneDrive - Microsoft\Documents\REPOSITORY\dstoolkit-forecasting\Data/Plots\constant

# %% [markdown]
# # Saving

# %%
# create a binary pickle file 
f = open(os.path.join(root, cfg_path.data_dir.output_path, 'dict_profiling.pkl'),"wb")
# write the python object (dict) to pickle file
pickle.dump(dict_profiling,f)
# close file
f.close()
